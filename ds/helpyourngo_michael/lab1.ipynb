# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json("helpyourngo.json")
df
# Out:
#                                                 name  last_updated  \
# 0                                      Aai Caretaker        2020.0
# 1                                            Aakriti        2015.0
# 2                         Aakash Maindwal Foundation        2016.0
# 3                                  Aaradhana Sanstha        2013.0
# 4    Action Against Hunger (Fight Hunger Foundation)        2019.0
# ..                                               ...           ...
# 683                  Abhinav Bahuuddeshiya Kalamanch        2020.0
# 684                                Abhaya Foundation        2015.0
# 685                                          Abhinav        2015.0
# 686            Action For Development Of Demos (ADD)        2014.0
# 687                Abhaya Kshethram Charitable Trust        2014.0
#
#                                                address  \
# 0    Room No. B/4, Ashok Nagar, Near Krishna Medica...
# ...

# %%
df.columns
# Out:
# Index(['name', 'last_updated', 'address', 'mobile', 'email', 'website',
#        'annual_expenditure', 'description'],
#       dtype='object')

# %%
len(df)
# Out:
# 688
