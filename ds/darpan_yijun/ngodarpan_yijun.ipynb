# %%
import pandas as pd

# %%
# !ls
# Out:
# 42621 Final_Data_ngodarpan.gov.in.xlsx
# ~$42621 Final_Data_ngodarpan.gov.in.xlsx
# 未命名.ipynb

# %%
df = pd.read_excel("42621 Final_Data_ngodarpan.gov.in.xlsx", nrows=100)

# %%
df.head()
# Out:
#                                 Name                    ngo url      Mobile  \
# 0                             PRAYAS                        NaN  9778080478
# 1        PONDICHERRYWOMENSCONFERENCE                        NaN  9443253238
# 2           SHABRI SAMAJ SEWA SAMITI  http://ssssamitibhind.org  7828393585
# 3  ANAND GANGA SAMAJIK SIKSHA SAMITI                        NaN  9450678180
# 4        Himaliyan Gram Vikas Samiti                        NaN  9412037018
#
#           UniqueID    Off phone1                        Email  \
# 0  OR/2009/0010000  06858-223440    director_prayas@yahoo.com
# 1  PY/2016/0100001  0413-2213238           surebe33@gmail.com
# 2  MP/2016/0100003  0751-1234689     ssssamitibhind@gmail.com
# 3  UP/2016/0100004  05566-281059  lovelyraivijendra@gmail.com
# 4  UA/2016/0100009  05964-213271           hgvs1990@gmail.com
#
#                                    Major Activities1 operational states db  \
# ...
