# %%
import boto3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket('my-bucket')

# %%
# !ls
# Out:
# Final_Data_Indiangoslist_v1.com.xlsx  indianngoEDA.ipynb
# Final_Data_ngoimpact.com.xlsx	      Untitled.ipynb

# %% [markdown]
# # Dataset Information:
# #### Data File: Final_Data_Indiangoslist_v1.com.xlsx
# #### Source: https://github.com/DaanMatch/Codebook/blob/main/ds/indiangolist_harish/Final_Data_Indiangoslist_v1.com.xlsx
# #### Type: xlsx
# #### Size: 30.1 MB

# %%
ngolist = pd.read_excel("Final_Data_Indiangoslist_v1.com.xlsx")

# %%
ngolist.head()
# Out:
#                                                  Url  \
# 0  http://www.indiangoslist.com/ngo-address/abo-t...
# 1  http://www.indiangoslist.com/ngo-address/aan-a...
# 2  http://www.indiangoslist.com/ngo-address/amik-...
# 3  http://www.indiangoslist.com/ngo-address/all-h...
# 4  http://www.indiangoslist.com/ngo-address/ane-a...
#
#                                  NGO Name        Unique Id  Chief Functionary  \
# 0                ABO TANI WELFARE SOCIETY  AR/2010/0027372         Mage Kamda
# 1                 AAN AAB WELFARE SOCIETY  AR/2010/0038998           Chairman
# 2                      AMIK MATAI SOCIETY  AR/2009/0009702         Rakhi Bora
# 3  ALL HAMAI DEVELOPMENT ASSOCIATION AHDA  AR/2012/0048621  Shri Tani Singyum
# 4                 ANE ABO WELFARE SOCIETY  AR/2010/0036913     Shri Hengo Bam
#
#             Chairman       Secretary       Treasurer  \
# 0         Mage Kamda  Paksing Maling     Tape Maling
# 1           Chairman             NaN             NaN
# 2      Ruzing Bellai       Sonem Kri   Dalimi Tayang
# 3  Shri Tani Singyum             NaN             NaN
# 4     Shri Hengo Bam    Mrs Yabi Bam  Shri Henya Bam
#
#                       Registered With          Type of NGO  \
# 0              Registrar of Societies              Society
# 1  Registrar of Cooperative Societies  Cooperative Society
# 2              Registrar of Societies              Society
# 3              Registrar of Societies              Society
# 4              Registrar of Societies              Society
#
#   Registration Number  ...              State     Telephone        Mobile  \
# 0         SR/ITA/2271  ...  Arunachal Pradesh  0360-2292635  9.436054e+09
# 1         SR/ITS/3251  ...  Arunachal Pradesh   9199-100015           NaN
# 2         SR ITA 2849  ...  Arunachal Pradesh  03804-222878  9.436227e+09
# 3         SR/ITA/8728  ...  Arunachal Pradesh  0379-2224167           NaN
# 4         SR/ITA/2616  ...  Arunachal Pradesh  0379-5222241  9.436411e+09
#
#                                              Address                 email  \
# 0  Village Kodak, P.O- and P.S- Taliha, Upper Sub...      atwsngo@yahoo.in
# 1                      Tili Lower Subansiri District    aaws2011@gmail.com
# 2  Amik Matai Society Post Box No 8 New Mekailian...   amikmatai@gmail.com
# 3  Rural works Division Daporijo Upper Subansiri ...  allgumsing@gmail.com
# 4      Basar, West Siang District Arunachal Pradesh.     aneabow@gmail.com
#
#                    Website           Fax  \
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2  http://ngo.india.gov.in  03804-222878
# 3                      NaN           NaN
# 4                      NaN           NaN
#
#                                      Ngo Information  \
# 0  ABO TANI WELFARE SOCIETY is located in Upper S...
# 1  AAN AAB WELFARE SOCIETY is located in Lower Su...
# 2  AMIK MATAI SOCIETY is located in Tezu Arunacha...
# 3  ALL HAMAI DEVELOPMENT ASSOCIATION AHDA is loca...
# 4  ANE ABO WELFARE SOCIETY is located in Arunacha...
#
#                                           Key Issues  \
# 0  This ABO TANI WELFARE SOCIETY NGO charity is w...
# 1  This AAN AAB WELFARE SOCIETY NGO charity is wo...
# 2  This AMIK MATAI SOCIETY NGO charity is working...
# 3  This ALL HAMAI DEVELOPMENT ASSOCIATION AHDA NG...
# 4  This ANE ABO WELFARE SOCIETY NGO charity is wo...
#
#                     Major Activities and Achivements
# 0  Flower Plantation, Weaving Material, Youth Dev...
# 1                                     Orphanage Home
# 2  Implemented the National Bamboo Mission progra...
# 3  Rural Development & Poverty Alleviation progra...
# 4  Maintenance and running of: (1) Treatment cum ...
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. Dataset Characteristics

# %%
print("Shape:",ngolist.shape)
print("Rows:",ngolist.shape[0])
print("Columns:",ngolist.shape[1])
print("Each row represents a unique NGO within India")
# Out:
# Shape: (56184, 24)
# Rows: 56184
# Columns: 24
# Each row represents a unique NGO within India

# %%
# number of values in dataset
len(ngolist)
# Out:
# 56184

# %%
# lists the variables in the dataset
v = pd.DataFrame(ngolist.columns)
v.rename({"0": "Columns"}, axis = 1, inplace = True)
v
# Out:
#                                    0
# 0                                Url
# 1                           NGO Name
# 2                          Unique Id
# 3                  Chief Functionary
# 4                           Chairman
# 5                          Secretary
# 6                          Treasurer
# 7                    Registered With
# 8                        Type of NGO
# 9                Registration Number
# 10              City of Registration
# 11             State of Registration
# 12              Date of Registration
# 13                              City
# 14                             State
# 15                         Telephone
# 16                            Mobile
# 17                           Address
# 18                             email
# 19                           Website
# 20                               Fax
# 21                   Ngo Information
# 22                        Key Issues
# 23  Major Activities and Achivements

# %% [markdown]
# # 3. EDA

# %%
counts = ngolist['State'].value_counts(ascending = False)
top_ten_states = counts[0:10]
top_ten_states
# Out:
# Uttar Pradesh     9293
# Maharashtra       6374
# West Bengal       5509
# Andhra Pradesh    3334
# Delhi             3290
# Tamil Nadu        3087
# Bihar             2871
# Orissa            2805
# Madhya Pradesh    2703
# Gujarat           2700
# Name: State, dtype: int64

# %%
# plotting the top 10 states with the highest number of NGO's 

sns.barplot(x = top_ten_states.values, y = top_ten_states.index, linewidth = 3)
sns.set(rc={'figure.figsize':(15,15)})
plt.ylabel('State')
plt.xlabel("Number of NGO's")
plt.title('Top ten states with highest number of NGOs')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### States with the highest number of NGO's observed here. Can further investigate if population has a relationship with the number of NGO's in a state.

# %%
result = ngolist.dtypes
result
# Out:
# Url                                  object
# NGO Name                             object
# Unique Id                            object
# Chief Functionary                    object
# Chairman                             object
# Secretary                            object
# Treasurer                            object
# Registered With                      object
# Type of NGO                          object
# Registration Number                  object
# City of Registration                 object
# State of Registration                object
# Date of Registration                 object
# City                                 object
# State                                object
# Telephone                            object
# Mobile                              float64
# Address                              object
# email                                object
# Website                              object
# Fax                                  object
# Ngo Information                      object
# Key Issues                           object
# Major Activities and Achivements     object
# dtype: object

# %% [markdown]
# #### Datatypes of each variable. "Object": represents mixed datatypes.

# %%
type_counts = ngolist['Type of NGO'].value_counts(ascending = False)
type_counts
# Out:
# Society                                               42155
# Trust                                                 11534
# Society Society                                         741
# Cooperative Society                                     693
# Trust Trust                                             459
# Section 25 Company                                      434
# Society Society Society                                  66
# Society Trust                                            32
# Trust Society                                            24
# Trust Trust Trust                                        18
# Cooperative Society Cooperative Society                   9
# Section 25 Company Section 25 Company                     4
# Trust Trust Society                                       3
# Section 25 Company Section 25 Company Section 25 C        2
# Society Society Trust                                     2
# Cooperative Society Trust                                 2
# Cooperative Society Cooperative Society Trust             1
# Society Section 25 Company                                1
# Section 25 Company Trust                                  1
# Society Section 25 Company Section 25 Company             1
# Society Society Section 25 Company                        1
# Trust Cooperative Society                                 1
# Name: Type of NGO, dtype: int64

# %%
sns.barplot(type_counts.index[0:5], type_counts.values[0:5])
# Out:
# /home/harish/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# #### Here, the most common NGO by type are listed. We can see there are a few key words that are recurrant, mainly being "Society", "Trust" and "Cooperative".
#
# #### Breaking the terminology down:
#
# #### Society: An NGO is typically a non-profit organization that is run by volunteers, while a Society is a group of people who have banded together for a common purpose (https://vakilsearch.com/blog/differences-between-an-ngo-and-a-society/)
#
# #### Trust: Trust is one of the forms of NGOs in India. These are registered to work on activities such as providing education, supplying medical relief, eradicating poverty, etc. Trusts are run as per the regulations laid down in the trust deed (https://swaritadvisors.com/blog/overview-of-difference-between-ngo-and-trust/#:~:text=Trust%20is%20one%20of%20the,down%20in%20the%20trust%20deed.)
#
# #### Cooperative: A Co-operative can be defined as “an autonomous association of persons united voluntarily to meet their common economic, social, and cultural needs and aspirations through a jointly-owned and democratically-controlled enterprise (https://www.618bees.com/article/604-differences-between-a-co-operative-society-and-an-ngo-foundation#:~:text=A%20Co%2Doperative%20can%20be,owned%20and%20democratically%2Dcontrolled%20enterprise.)

# %%
total = sum(type_counts.values)
percent_society = type_counts.values[0]/total * 100
percent_trust = type_counts.values[1]/total * 100
percent_cooperative = type_counts.values[3]/total * 100

percents_dict = {"society percentage": percent_society, "trust percentage": percent_trust, "cooperative percentage": percent_cooperative}
percents_dict
# Out:
# {'society percentage': 75.0302577246191,
#  'trust percentage': 20.52897622098818,
#  'cooperative percentage': 1.2334472447671936}

# %% [markdown]
# #### As seen here, 'society' make up the vast majority of NGO type in India at 75%, and 'trust' comes at second at around 20%.

# %% [markdown]
# #### However, it can be inferred through intuition that the classification groups are mostly redundant and can largely be placed into one of these three groups. For example, we could place "Trust Trust", and "Trust Trust Trust" into the single "Trust" Category.
#
# #### I will create a new data frame merging the obvious groups together, and then calculate the percentages by category and then visualize it to get a clearer picture of the data and observe if there are any differences.

# %%
merged_ngolist = ngolist.replace("Society Society", "Society")
merged_ngolist.replace("Trust Trust", "Trust", inplace = True)
merged_ngolist.replace("Society Society Society", "Society", inplace = True)
merged_ngolist.replace("Trust Trust Trust", "Trust", inplace = True)
merged_ngolist.loc[merged_ngolist['Type of NGO'].str.contains('Cooperative'), 'Type of NGO'] = 'Cooperative'
merged_ngolist
# Out:
#                                                      Url  \
# 0      http://www.indiangoslist.com/ngo-address/abo-t...
# 1      http://www.indiangoslist.com/ngo-address/aan-a...
# 2      http://www.indiangoslist.com/ngo-address/amik-...
# 3      http://www.indiangoslist.com/ngo-address/all-h...
# 4      http://www.indiangoslist.com/ngo-address/ane-a...
# ...                                                  ...
# 56179  http://www.indiangoslist.com/ngo-address/socie...
# 56180  http://www.indiangoslist.com/ngo-address/socie...
# 56181  http://www.indiangoslist.com/ngo-address/socie...
# 56182  http://www.indiangoslist.com/ngo-address/socie...
# 56183  http://www.indiangoslist.com/ngo-address/socie...
#
#                                                 NGO Name        Unique Id  \
# 0                               ABO TANI WELFARE SOCIETY  AR/2010/0027372
# 1                                AAN AAB WELFARE SOCIETY  AR/2010/0038998
# 2                                     AMIK MATAI SOCIETY  AR/2009/0009702
# 3                 ALL HAMAI DEVELOPMENT ASSOCIATION AHDA  AR/2012/0048621
# 4                                ANE ABO WELFARE SOCIETY  AR/2010/0036913
# ...                                                  ...              ...
# 56179  SOCIETY FOR EMPOWERMENT OF VILLAGES AND AGRICU...  MH/2009/0003328
# 56180    SOCIETY FOR INSTITUTE OF INFORMATION TECHNOLOGY  MH/2012/0050488
# 56181  SOCIETY FOR INTEGRATD DEVELOPMENT AND RESEARCH...  MH/2009/0005411
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...  MH/2010/0038456
# 56183  SOCIETY FOR PROMOTION OF AREA RESOURCE CENTRES...  MH/2009/0017850
#
#                   Chief Functionary                      Chairman  \
# 0                        Mage Kamda                    Mage Kamda
# 1                          Chairman                      Chairman
# 2                        Rakhi Bora                 Ruzing Bellai
# 3                 Shri Tani Singyum             Shri Tani Singyum
# 4                    Shri Hengo Bam                Shri Hengo Bam
# ...                             ...                           ...
# 56179              Krishna Shipkule              Krishna Shipkule
# 56180                 Sameer Chavan            Chandrakant Chavan
# 56181  Shri Balaso Vasantrao Jagtap  Shri Balaso Vasantrao Jagtap
# 56182   umesh ramchandra nilangekar   umesh ramchandra nilangekar
# 56183                  Sheela Patel                  Sheela Patel
#
#                             Secretary                       Treasurer  \
# 0                      Paksing Maling                     Tape Maling
# 1                                 NaN                             NaN
# 2                           Sonem Kri                   Dalimi Tayang
# 3                                 NaN                             NaN
# 4                        Mrs Yabi Bam                  Shri Henya Bam
# ...                               ...                             ...
# 56179              siddhappa vijapure                    mahesh pawar
# 56180                             NaN                             NaN
# 56181  Shri Abasaheb Ganpatrao Chavan  Sou Shantabai Vasantrao Jagtap
# 56182     sagar ramchandra nilangekar           vijay sudhakar jadhav
# 56183                             NaN                             NaN
#
#                           Registered With  Type of NGO  \
# 0                  Registrar of Societies      Society
# 1      Registrar of Cooperative Societies  Cooperative
# 2                  Registrar of Societies      Society
# 3                  Registrar of Societies      Society
# 4                  Registrar of Societies      Society
# ...                                   ...          ...
# 56179                Charity Commissioner      Society
# 56180                       Sub-Registrar        Trust
# 56181                Charity Commissioner      Society
# 56182                Charity Commissioner      Society
# 56183                Charity Commissioner        Trust
#
#                   Registration Number  ...              State     Telephone  \
# 0                         SR/ITA/2271  ...  Arunachal Pradesh  0360-2292635
# 1                         SR/ITS/3251  ...  Arunachal Pradesh   9199-100015
# 2                         SR ITA 2849  ...  Arunachal Pradesh  03804-222878
# 3                         SR/ITA/8728  ...  Arunachal Pradesh  0379-2224167
# 4                         SR/ITA/2616  ...  Arunachal Pradesh  0379-5222241
# ...                               ...  ...                ...           ...
# 56179                MAHA/8416/SATARA  ...        Maharashtra  02162-237192
# 56180                            1783  ...        Maharashtra  022-28063468
# 56181  Maha/190/2007, F- 11565/Sangli  ...        Maharashtra  02344-247114
# 56182              MAH/79/2003/F/8053  ...        Maharashtra  0240-2481857
# 56183                      BOM 798/84  ...        Maharashtra  022-23865053
#
#              Mobile                                            Address  \
# 0      9.436054e+09  Village Kodak, P.O- and P.S- Taliha, Upper Sub...
# 1               NaN                      Tili Lower Subansiri District
# 2      9.436227e+09  Amik Matai Society Post Box No 8 New Mekailian...
# 3               NaN  Rural works Division Daporijo Upper Subansiri ...
# 4      9.436411e+09      Basar, West Siang District Arunachal Pradesh.
# ...             ...                                                ...
# 56179  9.860925e+09  FF-17, Shahu Steduim, Opposite HP Petrol pump,...
# 56180  9.320303e+09  Shop No. 3, R. R. Shukla Compound, Carter Road...
# 56181  9.890202e+09  Head Office:- Society for Integrated Developme...
# 56182  9.422294e+09  Vishwamitra N7k 38 bajarang colony cidco auran...
# 56183           NaN  SPARC, 2nd Floor, Marathi Municipal School Bui...
#
#                                email                    Website           Fax  \
# 0                   atwsngo@yahoo.in                        NaN           NaN
# 1                 aaws2011@gmail.com                        NaN           NaN
# 2                amikmatai@gmail.com    http://ngo.india.gov.in  03804-222878
# 3               allgumsing@gmail.com                        NaN           NaN
# 4                  aneabow@gmail.com                        NaN           NaN
# ...                              ...                        ...           ...
# 56179     seva_satara@rediffmail.com                        NaN  02162-230288
# 56180           mailatsiit@gmail.com                        NaN           NaN
# 56181  smita_kamlekar@rediffmail.com                        NaN  02344-247195
# 56182         snehngo@rediffmail.com         http://snehngo.org  0240-2481857
# 56183           sparc@sparcindia.org  http://www.sparcindia.org  022-23887566
#
#                                          Ngo Information  \
# 0      ABO TANI WELFARE SOCIETY is located in Upper S...
# 1      AAN AAB WELFARE SOCIETY is located in Lower Su...
# 2      AMIK MATAI SOCIETY is located in Tezu Arunacha...
# 3      ALL HAMAI DEVELOPMENT ASSOCIATION AHDA is loca...
# 4      ANE ABO WELFARE SOCIETY is located in Arunacha...
# ...                                                  ...
# 56179  SOCIETY FOR EMPOWERMENT OF VILLAGES AND AGRICU...
# 56180  SOCIETY FOR INSTITUTE OF INFORMATION TECHNOLOG...
# 56181  SOCIETY FOR INTEGRATD DEVELOPMENT AND RESEARCH...
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...
# 56183  SOCIETY FOR PROMOTION OF AREA RESOURCE CENTRES...
#
#                                               Key Issues  \
# 0      This ABO TANI WELFARE SOCIETY NGO charity is w...
# 1      This AAN AAB WELFARE SOCIETY NGO charity is wo...
# 2      This AMIK MATAI SOCIETY NGO charity is working...
# 3      This ALL HAMAI DEVELOPMENT ASSOCIATION AHDA NG...
# 4      This ANE ABO WELFARE SOCIETY NGO charity is wo...
# ...                                                  ...
# 56179  This SOCIETY FOR EMPOWERMENT OF VILLAGES AND A...
# 56180  This SOCIETY FOR INSTITUTE OF INFORMATION TECH...
# 56181  This SOCIETY FOR INTEGRATD DEVELOPMENT AND RES...
# 56182  This SOCIETY FOR NATIONALISM EDUCATION AND HEA...
# 56183  This SOCIETY FOR PROMOTION OF AREA RESOURCE CE...
#
#                         Major Activities and Achivements
# 0      Flower Plantation, Weaving Material, Youth Dev...
# 1                                         Orphanage Home
# 2      Implemented the National Bamboo Mission progra...
# 3      Rural Development & Poverty Alleviation progra...
# 4      Maintenance and running of: (1) Treatment cum ...
# ...                                                  ...
# 56179  Expertisatin in Micro Plainning & P.R.A. Follo...
# 56180  To open / run / manage institute / college of ...
# 56181  We would like to introduce about that the soci...
# 56182  our ngo is working in rural areas.we have all ...
# 56183  The Society for the Promotion of Area Resource...
#
# [56184 rows x 24 columns]

# %%
merged_type_counts = merged_ngolist['Type of NGO'].value_counts(ascending = False)
merged_type_counts
# Out:
# Society                                               42962
# Trust                                                 12011
# Cooperative                                             706
# Section 25 Company                                      434
# Society Trust                                            32
# Trust Society                                            24
# Section 25 Company Section 25 Company                     4
# Trust Trust Society                                       3
# Section 25 Company Section 25 Company Section 25 C        2
# Society Society Trust                                     2
# Society Section 25 Company                                1
# Section 25 Company Trust                                  1
# Society Section 25 Company Section 25 Company             1
# Society Society Section 25 Company                        1
# Name: Type of NGO, dtype: int64

# %%
total_s = sum(merged_type_counts.values)
percent_society_re = merged_type_counts.values[0]/total_s * 100
percent_trust_re = merged_type_counts.values[1]/total_s * 100
percent_cooperative_re = merged_type_counts.values[2]/total_s * 100

percents_dict = {"society percentage": percent_society_re, "trust percentage": percent_trust_re, "cooperative percentage": percent_cooperative_re}
percents_dict
# Out:
# {'society percentage': 76.46660971094974,
#  'trust percentage': 21.377972376477288,
#  'cooperative percentage': 1.2565855047700412}

# %%
sns.barplot(merged_type_counts.index[0:5], merged_type_counts.values[0:5])
# Out:
# /home/harish/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# #### Although there is only a minimal change in percentage for each category, we have the data in a much cleaner format, with the vast majority of values being grouped into one of three categories.

# %%
na_ngolist = ngolist.dropna()
na_ngolist
# Out:
#                                                      Url  \
# 2      http://www.indiangoslist.com/ngo-address/amik-...
# 71     http://www.indiangoslist.com/ngo-address/disab...
# 97     http://www.indiangoslist.com/ngo-address/jhark...
# 101    http://www.indiangoslist.com/ngo-address/krush...
# 103    http://www.indiangoslist.com/ngo-address/ideal...
# ...                                                  ...
# 56142  http://www.indiangoslist.com/ngo-address/narri...
# 56154  http://www.indiangoslist.com/ngo-address/snehp...
# 56164  http://www.indiangoslist.com/ngo-address/rotar...
# 56174  http://www.indiangoslist.com/ngo-address/sns-f...
# 56182  http://www.indiangoslist.com/ngo-address/socie...
#
#                                                 NGO Name        Unique Id  \
# 2                                     AMIK MATAI SOCIETY  AR/2009/0009702
# 71                  DISABILITY RIGHTS ASSOCIATION OF GOA  GA/2009/0008767
# 97                                       JHARKHAND JYOTI  JH/2011/0042327
# 101                             KRUSHI GRAM VIKAS MANDAL  DN/2009/0015224
# 103     IDEAL AND NATURAL DISCIPLINARY ORGANIZATION INDO  JH/2012/0051747
# ...                                                  ...              ...
# 56142                                             NARRIE  GJ/2009/0014862
# 56154                                         SNEHPRAYAS  GJ/2010/0027764
# 56164            ROTARY CLUB OF MADRAS BOYS TOWN SOCIETY  TN/2009/0010649
# 56174                                     SNS FOUNDATION  MH/2009/0002444
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...  MH/2010/0038456
#
#                  Chief Functionary                         Chairman  \
# 2                       Rakhi Bora                    Ruzing Bellai
# 71                MR AVELINO DE SA                 MR AVELINO DE SA
# 97                  JAYANTA MANDAL              BHOLA SHANKAR GUPTA
# 101    Rathava Chandubhai Ramabhai  Bariya Dharmendrabhai Ramanbhai
# 103             Pawan Kumar Sharma                      Ramnath Ram
# ...                            ...                              ...
# 56142              DR MEHUL DAMANI                  DR MEHUL DAMANI
# 56154               satrugna sinah                      Vinay Mehta
# 56164             V K CHANDRAKUMAR                 V K CHANDRAKUMAR
# 56174                  mr jc anand                      mr jc anand
# 56182  umesh ramchandra nilangekar      umesh ramchandra nilangekar
#
#                          Secretary                  Treasurer  \
# 2                        Sonem Kri              Dalimi Tayang
# 71             MR VICTOR FERNANDES        MR VICTOR FERNANDES
# 97                  JAYANTA MANDAL          MRS SULATA MANDAL
# 101     Nayika Savitaben Kadavbhai  Bhil dahyabhai Seriyabhai
# 103             Pawan Kumar Sharma        Sourabh Kumar Singh
# ...                            ...                        ...
# 56142              DR SONAL DAMANI              PRAVINCHANDRA
# 56154                 Amod K Kanth             Subhash Narang
# 56164                 NIMISH TOLIA               KAMAL CHADDA
# 56174                  mr jc anand             mr sk tripathi
# 56182  sagar ramchandra nilangekar      vijay sudhakar jadhav
#
#               Registered With Type of NGO Registration Number  ...  \
# 2      Registrar of Societies     Society         SR ITA 2849  ...
# 71     Registrar of Societies     Society        259/Goa/2003  ...
# 97     Registrar of Societies     Society                 598  ...
# 101      Charity Commissioner       Trust     F/1362/Vadodara  ...
# 103    Registrar of Societies     Society        1074/2010-11  ...
# ...                       ...         ...                 ...  ...
# 56142    Charity Commissioner       Trust   E/16844/AHMEDABAD  ...
# 56154  Registrar of Societies     Society            S-200291  ...
# 56164  Registrar of Societies     Society             30/1988  ...
# 56174    Charity Commissioner       Trust      DLI(c) - T-405  ...
# 56182    Charity Commissioner     Society  MAH/79/2003/F/8053  ...
#
#                         State     Telephone        Mobile  \
# 2           Arunachal Pradesh  03804-222878  9.436227e+09
# 71                        Goa  0832-2427160  9.326121e+09
# 97                  Jharkhand  0657-2281833  9.204736e+09
# 101    Dadra and Nagar Haveli   0260-265464  9.879721e+09
# 103                 Jharkhand  0651-2290154  9.308404e+09
# ...                       ...           ...           ...
# 56142                 Gujarat  079-26304995  9.825050e+09
# 56154                 Gujarat  079-30070771  9.327759e+09
# 56164              Tamil Nadu  044-42139851  9.884075e+09
# 56174             Maharashtra  0253-2352756  9.420832e+09
# 56182             Maharashtra  0240-2481857  9.422294e+09
#
#                                                  Address  \
# 2      Amik Matai Society Post Box No 8 New Mekailian...
# 71            C/o STAR INVESTMENTS OPP. HEAD POST OFFICE
# 97     Jharkhand Jyoti, C/O B K Mandal Zone No: 6B, H...
# 101    Krushi Gram Vikas Mandal F-204. Padmavati Viha...
# 103    Chandani Chowk, Hatia P.O.- Hatia P.S.- Jagann...
# ...                                                  ...
# 56142  302, Jay shiva Tower, opp.Azad Society, Azad-A...
# 56154  401,Simandhar Avenue,8,Kailash Society, Behind...
# 56164  ROTARY CLUB OF MADRAS BOYS TOWN SOCIETY, I, II...
# 56174  SNS Foundation, Plot No.53, Mahatmanagar,Trimb...
# 56182  Vishwamitra N7k 38 bajarang colony cidco auran...
#
#                                 email                           Website  \
# 2                 amikmatai@gmail.com           http://ngo.india.gov.in
# 71              dragoa@rediffmail.com      http://www.disabilitygoa.com
# 97           jharkhandjyoti@gmail.com  http://www.jharkhandjyoti.org.in
# 101                Krushi12@gmail.com           http://ngo.india.gov.in
# 103              indoranchi@gmail.com              http://Indoranchi.in
# ...                               ...                               ...
# 56142        mehuldamani1@yahoo.co.in         http://www.planetwomen.in
# 56154  snehprayas_ahmedabad@yahoo.com         http://www.snehprayas.org
# 56164                   vkck@vsnl.net     http://rotaryclubofmadras.com
# 56174             snsf.nasik@snsf.org               http://www.snsf.org
# 56182          snehngo@rediffmail.com                http://snehngo.org
#
#                 Fax                                    Ngo Information  \
# 2      03804-222878  AMIK MATAI SOCIETY is located in Tezu Arunacha...
# 71     0832-2427160  DISABILITY RIGHTS ASSOCIATION OF GOA is locate...
# 97     0657-2281833  JHARKHAND JYOTI is located in JAMSHEDPUR Jhark...
# 101     0260-265464  KRUSHI GRAM VIKAS MANDAL is located in Silvass...
# 103    0651-2290154  IDEAL AND NATURAL DISCIPLINARY ORGANIZATION IN...
# ...             ...                                                ...
# 56142  079-26308008  NARRIE is located in Ahmedabad Gujarat . NARRI...
# 56154  02832-250309  SNEHPRAYAS is located in Bhuj Gujarat . SNEHPR...
# 56164  044-28217274  ROTARY CLUB OF MADRAS BOYS TOWN SOCIETY is loc...
# 56174  0253-2352756  SNS FOUNDATION is located in Nasik Maharashtra...
# 56182  0240-2481857  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...
#
#                                               Key Issues  \
# 2      This AMIK MATAI SOCIETY NGO charity is working...
# 71     This DISABILITY RIGHTS ASSOCIATION OF GOA NGO ...
# 97     This JHARKHAND JYOTI NGO charity is working on...
# 101    This KRUSHI GRAM VIKAS MANDAL NGO charity is w...
# 103    This IDEAL AND NATURAL DISCIPLINARY ORGANIZATI...
# ...                                                  ...
# 56142  This NARRIE NGO charity is working on Key Issu...
# 56154  This SNEHPRAYAS NGO charity is working on Key ...
# 56164  This ROTARY CLUB OF MADRAS BOYS TOWN SOCIETY N...
# 56174  This SNS FOUNDATION NGO charity is working on ...
# 56182  This SOCIETY FOR NATIONALISM EDUCATION AND HEA...
#
#                         Major Activities and Achivements
# 2      Implemented the National Bamboo Mission progra...
# 71     Winner of the Godfrey Phillips Bravey Award fo...
# 97     Livilehood prototype, Tribal Affairs, Agricult...
# 101    KRUSHI GRAM VIKAS MANDAL Year 2007-08 Annual R...
# 103    Women Empowerment Programme SHG Formation And ...
# ...                                                  ...
# 56142  we have developed various models,Cds, posters,...
# 56154  � Basic needs and rights of children are synon...
# 56164  Boys� Town Society has established Boys home f...
# 56174  SNS Foundation (SNSF) or Sant Nischal Singh Fo...
# 56182  our ngo is working in rural areas.we have all ...
#
# [3079 rows x 24 columns]

# %% [markdown]
# #### NGO List with all missing values in rows dropped. Through it could be potentially useful, it causes over 50 thousand rows to be expunged from the original dataset, which is far too much information to lose when trying to analyze the overall dataset in any meaningful sense, especially when most of the missing values are in irrelevant columns for analysis such as telephone or mobile.

# %%
merged_ngolist.groupby(["State", "Type of NGO"]).count()
# Out:
#                                                                                 Url  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                     3
#                            Society                                               16
#                            Trust                                                  4
# Andhra Pradesh             Cooperative                                           22
#                            Section 25 Company                                    24
# ...                                                                             ...
# West Bengal                Cooperative                                           24
#                            Section 25 Company                                    29
#                            Section 25 Company Section 25 Company Section 25 C     1
#                            Society                                             5078
#                            Trust                                                377
#
#                                                                                NGO Name  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                         3
#                            Society                                                   16
#                            Trust                                                      4
# Andhra Pradesh             Cooperative                                               22
#                            Section 25 Company                                        24
# ...                                                                                 ...
# West Bengal                Cooperative                                               24
#                            Section 25 Company                                        29
#                            Section 25 Company Section 25 Company Section 25 C         1
#                            Society                                                 5077
#                            Trust                                                    377
#
#                                                                                Unique Id  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                          3
#                            Society                                                    16
#                            Trust                                                       4
# Andhra Pradesh             Cooperative                                                22
#                            Section 25 Company                                         24
# ...                                                                                  ...
# West Bengal                Cooperative                                                24
#                            Section 25 Company                                         29
#                            Section 25 Company Section 25 Company Section 25 C          1
#                            Society                                                  5078
#                            Trust                                                     377
#
#                                                                                Chief Functionary  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                  3
#                            Society                                                            16
#                            Trust                                                               4
# Andhra Pradesh             Cooperative                                                        22
#                            Section 25 Company                                                 24
# ...                                                                                          ...
# West Bengal                Cooperative                                                        24
#                            Section 25 Company                                                 29
#                            Section 25 Company Section 25 Company Section 25 C                  1
#                            Society                                                          5078
#                            Trust                                                             377
#
#                                                                                Chairman  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                         3
#                            Society                                                   16
#                            Trust                                                      4
# Andhra Pradesh             Cooperative                                               22
#                            Section 25 Company                                        23
# ...                                                                                 ...
# West Bengal                Cooperative                                               24
#                            Section 25 Company                                        29
#                            Section 25 Company Section 25 Company Section 25 C         1
#                            Society                                                 5054
#                            Trust                                                    376
#
#                                                                                Secretary  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                          2
#                            Society                                                    14
#                            Trust                                                       3
# Andhra Pradesh             Cooperative                                                18
#                            Section 25 Company                                         11
# ...                                                                                  ...
# West Bengal                Cooperative                                                22
#                            Section 25 Company                                         17
#                            Section 25 Company Section 25 Company Section 25 C          0
#                            Society                                                  4848
#                            Trust                                                     317
#
#                                                                                Treasurer  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                          2
#                            Society                                                    14
#                            Trust                                                       3
# Andhra Pradesh             Cooperative                                                17
#                            Section 25 Company                                         12
# ...                                                                                  ...
# West Bengal                Cooperative                                                22
#                            Section 25 Company                                         18
#                            Section 25 Company Section 25 Company Section 25 C          0
#                            Society                                                  4794
#                            Trust                                                     309
#
#                                                                                Registered With  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                3
#                            Society                                                          16
#                            Trust                                                             4
# Andhra Pradesh             Cooperative                                                      22
#                            Section 25 Company                                               24
# ...                                                                                        ...
# West Bengal                Cooperative                                                      24
#                            Section 25 Company                                               29
#                            Section 25 Company Section 25 Company Section 25 C                1
#                            Society                                                        5078
#                            Trust                                                           377
#
#                                                                                Registration Number  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                    3
#                            Society                                                              16
#                            Trust                                                                 4
# Andhra Pradesh             Cooperative                                                          22
#                            Section 25 Company                                                   24
# ...                                                                                            ...
# West Bengal                Cooperative                                                          24
#                            Section 25 Company                                                   29
#                            Section 25 Company Section 25 Company Section 25 C                    1
#                            Society                                                            5078
#                            Trust                                                               376
#
#                                                                                City of Registration  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                     3
#                            Society                                                               16
#                            Trust                                                                  4
# Andhra Pradesh             Cooperative                                                           22
#                            Section 25 Company                                                    24
# ...                                                                                             ...
# West Bengal                Cooperative                                                           24
#                            Section 25 Company                                                    29
#                            Section 25 Company Section 25 Company Section 25 C                     1
#                            Society                                                             5057
#                            Trust                                                                376
#
#                                                                                ...  \
# State                      Type of NGO                                         ...
# Andaman and Nicobar Island Section 25 Company                                  ...
#                            Society                                             ...
#                            Trust                                               ...
# Andhra Pradesh             Cooperative                                         ...
#                            Section 25 Company                                  ...
# ...                                                                            ...
# West Bengal                Cooperative                                         ...
#                            Section 25 Company                                  ...
#                            Section 25 Company Section 25 Company Section 25 C  ...
#                            Society                                             ...
#                            Trust                                               ...
#
#                                                                                City  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                     2
#                            Society                                               16
#                            Trust                                                  3
# Andhra Pradesh             Cooperative                                           20
#                            Section 25 Company                                    23
# ...                                                                             ...
# West Bengal                Cooperative                                           22
#                            Section 25 Company                                    26
#                            Section 25 Company Section 25 Company Section 25 C     1
#                            Society                                             4680
#                            Trust                                                356
#
#                                                                                Telephone  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                          3
#                            Society                                                    16
#                            Trust                                                       4
# Andhra Pradesh             Cooperative                                                22
#                            Section 25 Company                                         24
# ...                                                                                  ...
# West Bengal                Cooperative                                                24
#                            Section 25 Company                                         29
#                            Section 25 Company Section 25 Company Section 25 C          1
#                            Society                                                  5078
#                            Trust                                                     377
#
#                                                                                Mobile  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                       1
#                            Society                                                 16
#                            Trust                                                    3
# Andhra Pradesh             Cooperative                                             17
#                            Section 25 Company                                      16
# ...                                                                               ...
# West Bengal                Cooperative                                             20
#                            Section 25 Company                                      25
#                            Section 25 Company Section 25 Company Section 25 C       1
#                            Society                                               4541
#                            Trust                                                  308
#
#                                                                                Address  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                        3
#                            Society                                                  16
#                            Trust                                                     4
# Andhra Pradesh             Cooperative                                              22
#                            Section 25 Company                                       24
# ...                                                                                ...
# West Bengal                Cooperative                                              24
#                            Section 25 Company                                       29
#                            Section 25 Company Section 25 Company Section 25 C        1
#                            Society                                                5075
#                            Trust                                                   377
#
#                                                                                email  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                      3
#                            Society                                                16
#                            Trust                                                   4
# Andhra Pradesh             Cooperative                                            22
#                            Section 25 Company                                     24
# ...                                                                              ...
# West Bengal                Cooperative                                            24
#                            Section 25 Company                                     29
#                            Section 25 Company Section 25 Company Section 25 C      1
#                            Society                                              5075
#                            Trust                                                 377
#
#                                                                                Website  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                        0
#                            Society                                                   3
#                            Trust                                                     1
# Andhra Pradesh             Cooperative                                               6
#                            Section 25 Company                                       15
# ...                                                                                ...
# West Bengal                Cooperative                                               3
#                            Section 25 Company                                       16
#                            Section 25 Company Section 25 Company Section 25 C        1
#                            Society                                                 835
#                            Trust                                                   136
#
#                                                                                Fax  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                    0
#                            Society                                               4
#                            Trust                                                 1
# Andhra Pradesh             Cooperative                                           4
#                            Section 25 Company                                   10
# ...                                                                            ...
# West Bengal                Cooperative                                           4
#                            Section 25 Company                                   11
#                            Section 25 Company Section 25 Company Section 25 C    1
#                            Society                                             779
#                            Trust                                                77
#
#                                                                                Ngo Information  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                3
#                            Society                                                          16
#                            Trust                                                             4
# Andhra Pradesh             Cooperative                                                      22
#                            Section 25 Company                                               24
# ...                                                                                        ...
# West Bengal                Cooperative                                                      24
#                            Section 25 Company                                               29
#                            Section 25 Company Section 25 Company Section 25 C                1
#                            Society                                                        5078
#                            Trust                                                           377
#
#                                                                                Key Issues  \
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                           3
#                            Society                                                     14
#                            Trust                                                        3
# Andhra Pradesh             Cooperative                                                 17
#                            Section 25 Company                                          20
# ...                                                                                   ...
# West Bengal                Cooperative                                                 23
#                            Section 25 Company                                          24
#                            Section 25 Company Section 25 Company Section 25 C           1
#                            Society                                                   4238
#                            Trust                                                      274
#
#                                                                                Major Activities and Achivements
# State                      Type of NGO
# Andaman and Nicobar Island Section 25 Company                                                                 3
#                            Society                                                                           16
#                            Trust                                                                              4
# Andhra Pradesh             Cooperative                                                                       22
#                            Section 25 Company                                                                24
# ...                                                                                                         ...
# West Bengal                Cooperative                                                                       24
#                            Section 25 Company                                                                29
#                            Section 25 Company Section 25 Company Section 25 C                                 1
#                            Society                                                                         5045
#                            Trust                                                                            367
#
# [148 rows x 22 columns]

# %%
merged_ngolist.groupby(["State", "Type of NGO"]).count()["Unique Id"]
# Out:
# State                       Type of NGO
# Andaman and Nicobar Island  Section 25 Company                                       3
#                             Society                                                 16
#                             Trust                                                    4
# Andhra Pradesh              Cooperative                                             22
#                             Section 25 Company                                      24
#                                                                                   ...
# West Bengal                 Cooperative                                             24
#                             Section 25 Company                                      29
#                             Section 25 Company Section 25 Company Section 25 C       1
#                             Society                                               5078
#                             Trust                                                  377
# Name: Unique Id, Length: 148, dtype: int64

# %% [markdown]
# # 4. Data Cleaning

# %%
merged_ngolist
# Out:
#                                                      Url  \
# 0      http://www.indiangoslist.com/ngo-address/abo-t...
# 1      http://www.indiangoslist.com/ngo-address/aan-a...
# 2      http://www.indiangoslist.com/ngo-address/amik-...
# 3      http://www.indiangoslist.com/ngo-address/all-h...
# 4      http://www.indiangoslist.com/ngo-address/ane-a...
# ...                                                  ...
# 56179  http://www.indiangoslist.com/ngo-address/socie...
# 56180  http://www.indiangoslist.com/ngo-address/socie...
# 56181  http://www.indiangoslist.com/ngo-address/socie...
# 56182  http://www.indiangoslist.com/ngo-address/socie...
# 56183  http://www.indiangoslist.com/ngo-address/socie...
#
#                                                 NGO Name        Unique Id  \
# 0                               ABO TANI WELFARE SOCIETY  AR/2010/0027372
# 1                                AAN AAB WELFARE SOCIETY  AR/2010/0038998
# 2                                     AMIK MATAI SOCIETY  AR/2009/0009702
# 3                 ALL HAMAI DEVELOPMENT ASSOCIATION AHDA  AR/2012/0048621
# 4                                ANE ABO WELFARE SOCIETY  AR/2010/0036913
# ...                                                  ...              ...
# 56179  SOCIETY FOR EMPOWERMENT OF VILLAGES AND AGRICU...  MH/2009/0003328
# 56180    SOCIETY FOR INSTITUTE OF INFORMATION TECHNOLOGY  MH/2012/0050488
# 56181  SOCIETY FOR INTEGRATD DEVELOPMENT AND RESEARCH...  MH/2009/0005411
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...  MH/2010/0038456
# 56183  SOCIETY FOR PROMOTION OF AREA RESOURCE CENTRES...  MH/2009/0017850
#
#                   Chief Functionary                      Chairman  \
# 0                        Mage Kamda                    Mage Kamda
# 1                          Chairman                      Chairman
# 2                        Rakhi Bora                 Ruzing Bellai
# 3                 Shri Tani Singyum             Shri Tani Singyum
# 4                    Shri Hengo Bam                Shri Hengo Bam
# ...                             ...                           ...
# 56179              Krishna Shipkule              Krishna Shipkule
# 56180                 Sameer Chavan            Chandrakant Chavan
# 56181  Shri Balaso Vasantrao Jagtap  Shri Balaso Vasantrao Jagtap
# 56182   umesh ramchandra nilangekar   umesh ramchandra nilangekar
# 56183                  Sheela Patel                  Sheela Patel
#
#                             Secretary                       Treasurer  \
# 0                      Paksing Maling                     Tape Maling
# 1                                 NaN                             NaN
# 2                           Sonem Kri                   Dalimi Tayang
# 3                                 NaN                             NaN
# 4                        Mrs Yabi Bam                  Shri Henya Bam
# ...                               ...                             ...
# 56179              siddhappa vijapure                    mahesh pawar
# 56180                             NaN                             NaN
# 56181  Shri Abasaheb Ganpatrao Chavan  Sou Shantabai Vasantrao Jagtap
# 56182     sagar ramchandra nilangekar           vijay sudhakar jadhav
# 56183                             NaN                             NaN
#
#                           Registered With  Type of NGO  \
# 0                  Registrar of Societies      Society
# 1      Registrar of Cooperative Societies  Cooperative
# 2                  Registrar of Societies      Society
# 3                  Registrar of Societies      Society
# 4                  Registrar of Societies      Society
# ...                                   ...          ...
# 56179                Charity Commissioner      Society
# 56180                       Sub-Registrar        Trust
# 56181                Charity Commissioner      Society
# 56182                Charity Commissioner      Society
# 56183                Charity Commissioner        Trust
#
#                   Registration Number  ...              State     Telephone  \
# 0                         SR/ITA/2271  ...  Arunachal Pradesh  0360-2292635
# 1                         SR/ITS/3251  ...  Arunachal Pradesh   9199-100015
# 2                         SR ITA 2849  ...  Arunachal Pradesh  03804-222878
# 3                         SR/ITA/8728  ...  Arunachal Pradesh  0379-2224167
# 4                         SR/ITA/2616  ...  Arunachal Pradesh  0379-5222241
# ...                               ...  ...                ...           ...
# 56179                MAHA/8416/SATARA  ...        Maharashtra  02162-237192
# 56180                            1783  ...        Maharashtra  022-28063468
# 56181  Maha/190/2007, F- 11565/Sangli  ...        Maharashtra  02344-247114
# 56182              MAH/79/2003/F/8053  ...        Maharashtra  0240-2481857
# 56183                      BOM 798/84  ...        Maharashtra  022-23865053
#
#              Mobile                                            Address  \
# 0      9.436054e+09  Village Kodak, P.O- and P.S- Taliha, Upper Sub...
# 1               NaN                      Tili Lower Subansiri District
# 2      9.436227e+09  Amik Matai Society Post Box No 8 New Mekailian...
# 3               NaN  Rural works Division Daporijo Upper Subansiri ...
# 4      9.436411e+09      Basar, West Siang District Arunachal Pradesh.
# ...             ...                                                ...
# 56179  9.860925e+09  FF-17, Shahu Steduim, Opposite HP Petrol pump,...
# 56180  9.320303e+09  Shop No. 3, R. R. Shukla Compound, Carter Road...
# 56181  9.890202e+09  Head Office:- Society for Integrated Developme...
# 56182  9.422294e+09  Vishwamitra N7k 38 bajarang colony cidco auran...
# 56183           NaN  SPARC, 2nd Floor, Marathi Municipal School Bui...
#
#                                email                    Website           Fax  \
# 0                   atwsngo@yahoo.in                        NaN           NaN
# 1                 aaws2011@gmail.com                        NaN           NaN
# 2                amikmatai@gmail.com    http://ngo.india.gov.in  03804-222878
# 3               allgumsing@gmail.com                        NaN           NaN
# 4                  aneabow@gmail.com                        NaN           NaN
# ...                              ...                        ...           ...
# 56179     seva_satara@rediffmail.com                        NaN  02162-230288
# 56180           mailatsiit@gmail.com                        NaN           NaN
# 56181  smita_kamlekar@rediffmail.com                        NaN  02344-247195
# 56182         snehngo@rediffmail.com         http://snehngo.org  0240-2481857
# 56183           sparc@sparcindia.org  http://www.sparcindia.org  022-23887566
#
#                                          Ngo Information  \
# 0      ABO TANI WELFARE SOCIETY is located in Upper S...
# 1      AAN AAB WELFARE SOCIETY is located in Lower Su...
# 2      AMIK MATAI SOCIETY is located in Tezu Arunacha...
# 3      ALL HAMAI DEVELOPMENT ASSOCIATION AHDA is loca...
# 4      ANE ABO WELFARE SOCIETY is located in Arunacha...
# ...                                                  ...
# 56179  SOCIETY FOR EMPOWERMENT OF VILLAGES AND AGRICU...
# 56180  SOCIETY FOR INSTITUTE OF INFORMATION TECHNOLOG...
# 56181  SOCIETY FOR INTEGRATD DEVELOPMENT AND RESEARCH...
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...
# 56183  SOCIETY FOR PROMOTION OF AREA RESOURCE CENTRES...
#
#                                               Key Issues  \
# 0      This ABO TANI WELFARE SOCIETY NGO charity is w...
# 1      This AAN AAB WELFARE SOCIETY NGO charity is wo...
# 2      This AMIK MATAI SOCIETY NGO charity is working...
# 3      This ALL HAMAI DEVELOPMENT ASSOCIATION AHDA NG...
# 4      This ANE ABO WELFARE SOCIETY NGO charity is wo...
# ...                                                  ...
# 56179  This SOCIETY FOR EMPOWERMENT OF VILLAGES AND A...
# 56180  This SOCIETY FOR INSTITUTE OF INFORMATION TECH...
# 56181  This SOCIETY FOR INTEGRATD DEVELOPMENT AND RES...
# 56182  This SOCIETY FOR NATIONALISM EDUCATION AND HEA...
# 56183  This SOCIETY FOR PROMOTION OF AREA RESOURCE CE...
#
#                         Major Activities and Achivements
# 0      Flower Plantation, Weaving Material, Youth Dev...
# 1                                         Orphanage Home
# 2      Implemented the National Bamboo Mission progra...
# 3      Rural Development & Poverty Alleviation progra...
# 4      Maintenance and running of: (1) Treatment cum ...
# ...                                                  ...
# 56179  Expertisatin in Micro Plainning & P.R.A. Follo...
# 56180  To open / run / manage institute / college of ...
# 56181  We would like to introduce about that the soci...
# 56182  our ngo is working in rural areas.we have all ...
# 56183  The Society for the Promotion of Area Resource...
#
# [56184 rows x 24 columns]

# %%
merged_ngolist['Ngo Information']= merged_ngolist['Ngo Information'].map(str. lower)
merged_ngolist = merged_ngolist.astype({"Key Issues": str, "Major Activities and Achivements": str})
merged_ngolist['Key Issues']= merged_ngolist['Key Issues'].map(str. lower)
merged_ngolist["Major Activities and Achivements"] = merged_ngolist["Major Activities and Achivements"].map(str. lower)
merged_ngolist
# Out:
#                                                      Url  \
# 0      http://www.indiangoslist.com/ngo-address/abo-t...
# 1      http://www.indiangoslist.com/ngo-address/aan-a...
# 2      http://www.indiangoslist.com/ngo-address/amik-...
# 3      http://www.indiangoslist.com/ngo-address/all-h...
# 4      http://www.indiangoslist.com/ngo-address/ane-a...
# ...                                                  ...
# 56179  http://www.indiangoslist.com/ngo-address/socie...
# 56180  http://www.indiangoslist.com/ngo-address/socie...
# 56181  http://www.indiangoslist.com/ngo-address/socie...
# 56182  http://www.indiangoslist.com/ngo-address/socie...
# 56183  http://www.indiangoslist.com/ngo-address/socie...
#
#                                                 NGO Name        Unique Id  \
# 0                               ABO TANI WELFARE SOCIETY  AR/2010/0027372
# 1                                AAN AAB WELFARE SOCIETY  AR/2010/0038998
# 2                                     AMIK MATAI SOCIETY  AR/2009/0009702
# 3                 ALL HAMAI DEVELOPMENT ASSOCIATION AHDA  AR/2012/0048621
# 4                                ANE ABO WELFARE SOCIETY  AR/2010/0036913
# ...                                                  ...              ...
# 56179  SOCIETY FOR EMPOWERMENT OF VILLAGES AND AGRICU...  MH/2009/0003328
# 56180    SOCIETY FOR INSTITUTE OF INFORMATION TECHNOLOGY  MH/2012/0050488
# 56181  SOCIETY FOR INTEGRATD DEVELOPMENT AND RESEARCH...  MH/2009/0005411
# 56182  SOCIETY FOR NATIONALISM EDUCATION AND HEALTH A...  MH/2010/0038456
# 56183  SOCIETY FOR PROMOTION OF AREA RESOURCE CENTRES...  MH/2009/0017850
#
#                   Chief Functionary                      Chairman  \
# 0                        Mage Kamda                    Mage Kamda
# 1                          Chairman                      Chairman
# 2                        Rakhi Bora                 Ruzing Bellai
# 3                 Shri Tani Singyum             Shri Tani Singyum
# 4                    Shri Hengo Bam                Shri Hengo Bam
# ...                             ...                           ...
# 56179              Krishna Shipkule              Krishna Shipkule
# 56180                 Sameer Chavan            Chandrakant Chavan
# 56181  Shri Balaso Vasantrao Jagtap  Shri Balaso Vasantrao Jagtap
# 56182   umesh ramchandra nilangekar   umesh ramchandra nilangekar
# 56183                  Sheela Patel                  Sheela Patel
#
#                             Secretary                       Treasurer  \
# 0                      Paksing Maling                     Tape Maling
# 1                                 NaN                             NaN
# 2                           Sonem Kri                   Dalimi Tayang
# 3                                 NaN                             NaN
# 4                        Mrs Yabi Bam                  Shri Henya Bam
# ...                               ...                             ...
# 56179              siddhappa vijapure                    mahesh pawar
# 56180                             NaN                             NaN
# 56181  Shri Abasaheb Ganpatrao Chavan  Sou Shantabai Vasantrao Jagtap
# 56182     sagar ramchandra nilangekar           vijay sudhakar jadhav
# 56183                             NaN                             NaN
#
#                           Registered With  Type of NGO  \
# 0                  Registrar of Societies      Society
# 1      Registrar of Cooperative Societies  Cooperative
# 2                  Registrar of Societies      Society
# 3                  Registrar of Societies      Society
# 4                  Registrar of Societies      Society
# ...                                   ...          ...
# 56179                Charity Commissioner      Society
# 56180                       Sub-Registrar        Trust
# 56181                Charity Commissioner      Society
# 56182                Charity Commissioner      Society
# 56183                Charity Commissioner        Trust
#
#                   Registration Number  ...              State     Telephone  \
# 0                         SR/ITA/2271  ...  Arunachal Pradesh  0360-2292635
# 1                         SR/ITS/3251  ...  Arunachal Pradesh   9199-100015
# 2                         SR ITA 2849  ...  Arunachal Pradesh  03804-222878
# 3                         SR/ITA/8728  ...  Arunachal Pradesh  0379-2224167
# 4                         SR/ITA/2616  ...  Arunachal Pradesh  0379-5222241
# ...                               ...  ...                ...           ...
# 56179                MAHA/8416/SATARA  ...        Maharashtra  02162-237192
# 56180                            1783  ...        Maharashtra  022-28063468
# 56181  Maha/190/2007, F- 11565/Sangli  ...        Maharashtra  02344-247114
# 56182              MAH/79/2003/F/8053  ...        Maharashtra  0240-2481857
# 56183                      BOM 798/84  ...        Maharashtra  022-23865053
#
#              Mobile                                            Address  \
# 0      9.436054e+09  Village Kodak, P.O- and P.S- Taliha, Upper Sub...
# 1               NaN                      Tili Lower Subansiri District
# 2      9.436227e+09  Amik Matai Society Post Box No 8 New Mekailian...
# 3               NaN  Rural works Division Daporijo Upper Subansiri ...
# 4      9.436411e+09      Basar, West Siang District Arunachal Pradesh.
# ...             ...                                                ...
# 56179  9.860925e+09  FF-17, Shahu Steduim, Opposite HP Petrol pump,...
# 56180  9.320303e+09  Shop No. 3, R. R. Shukla Compound, Carter Road...
# 56181  9.890202e+09  Head Office:- Society for Integrated Developme...
# 56182  9.422294e+09  Vishwamitra N7k 38 bajarang colony cidco auran...
# 56183           NaN  SPARC, 2nd Floor, Marathi Municipal School Bui...
#
#                                email                    Website           Fax  \
# 0                   atwsngo@yahoo.in                        NaN           NaN
# 1                 aaws2011@gmail.com                        NaN           NaN
# 2                amikmatai@gmail.com    http://ngo.india.gov.in  03804-222878
# 3               allgumsing@gmail.com                        NaN           NaN
# 4                  aneabow@gmail.com                        NaN           NaN
# ...                              ...                        ...           ...
# 56179     seva_satara@rediffmail.com                        NaN  02162-230288
# 56180           mailatsiit@gmail.com                        NaN           NaN
# 56181  smita_kamlekar@rediffmail.com                        NaN  02344-247195
# 56182         snehngo@rediffmail.com         http://snehngo.org  0240-2481857
# 56183           sparc@sparcindia.org  http://www.sparcindia.org  022-23887566
#
#                                          Ngo Information  \
# 0      abo tani welfare society is located in upper s...
# 1      aan aab welfare society is located in lower su...
# 2      amik matai society is located in tezu arunacha...
# 3      all hamai development association ahda is loca...
# 4      ane abo welfare society is located in arunacha...
# ...                                                  ...
# 56179  society for empowerment of villages and agricu...
# 56180  society for institute of information technolog...
# 56181  society for integratd development and research...
# 56182  society for nationalism education and health a...
# 56183  society for promotion of area resource centres...
#
#                                               Key Issues  \
# 0      this abo tani welfare society ngo charity is w...
# 1      this aan aab welfare society ngo charity is wo...
# 2      this amik matai society ngo charity is working...
# 3      this all hamai development association ahda ng...
# 4      this ane abo welfare society ngo charity is wo...
# ...                                                  ...
# 56179  this society for empowerment of villages and a...
# 56180  this society for institute of information tech...
# 56181  this society for integratd development and res...
# 56182  this society for nationalism education and hea...
# 56183  this society for promotion of area resource ce...
#
#                         Major Activities and Achivements
# 0      flower plantation, weaving material, youth dev...
# 1                                         orphanage home
# 2      implemented the national bamboo mission progra...
# 3      rural development & poverty alleviation progra...
# 4      maintenance and running of: (1) treatment cum ...
# ...                                                  ...
# 56179  expertisatin in micro plainning & p.r.a. follo...
# 56180  to open / run / manage institute / college of ...
# 56181  we would like to introduce about that the soci...
# 56182  our ngo is working in rural areas.we have all ...
# 56183  the society for the promotion of area resource...
#
# [56184 rows x 24 columns]

# %% [markdown]
# # Datafile 2

# %% [markdown]
# # 1. Dataset Information
#
# #### Data File: 'Final_Data_ngoimpact.com.xlsx'
# #### Source: https://github.com/DaanMatch/Codebook/blob/main/ds/ngo_impact_harish/Final_Data_ngoimpact.com.xlsx
# #### Type: xlsx
# #### Size: 381 KB

# %%
ngoimpact = pd.read_excel('Final_Data_ngoimpact.com.xlsx')
ngoimpact
# Out:
#                                                   Link  \
# 0    http://www.ngoimpact.com/ngos/turning-point-fo...
# 1    http://www.ngoimpact.com/ngos/basic-research-e...
# 2    http://www.ngoimpact.com/ngos/divya-jyothi-cha...
# 3    http://www.ngoimpact.com/ngos/atma-foundation#...
# 4    http://www.ngoimpact.com/ngos/calcutta-rescue#...
# ..                                                 ...
# 546  http://www.ngoimpact.com/ngos/youth-union-for-...
# 547  http://www.ngoimpact.com/ngos/yugant-foundatio...
# 548  http://www.ngoimpact.com/ngos/zakat-foundation...
# 549  http://www.ngoimpact.com/ngos/zmq-development#...
# 550  http://www.ngoimpact.com/ngos/youth-for-seva#p...
#
#                                                  About  \
# 0    TPF is a not for profit, national level volunt...
# 1    Basic Research Education And Development Socie...
# 2    “ Divya Jyothi Charitable Trust” for the blind...
# 3    ATMA Foundation is an NGO committed to empower...
# 4    Calcutta Rescue (CR) is a non – governmental o...
# ..                                                 ...
# 546  YOUTH UNION FOR VARIOUS ACTION is located I Gu...
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
# 550                                                NaN
#
#                                                 VISION  \
# 0    VisionThe vision of the organisation is to dev...
# 1    To inculcate the thirst for knowledge among st...
# 2    Empowering the visually impaired so that they ...
# 3    MissionEmpowering individuals, families & soci...
# 4    To reach out to more number of people living o...
# ..                                                 ...
# 546                                                NaN
# 547                                                NaN
# 548                                                NaN
# 549                                                NaN
# 550                                                NaN
#
#     Your organisation is registered as Permanent account number (PAN)  \
# 0                   Charitable Society                     AABTT1084A
# 1                   Charitable Society                     AAATB4485E
# 2              Public Charitable Trust                     AABTD4733A
# 3              Public Charitable Trust                     AADTA2673C
# 4                   Charitable Society                     AAATC2014N
# ..                                 ...                            ...
# 546            Public Charitable Trust                     AAATY2186R
# 547                 Charitable Society                     AAAAY2377F
# 548            Public Charitable Trust                     AAATZ0336Q
# 549                 Charitable Society                     AAACZ5514B
# 550            Public Charitable Trust                     AAATY3178K
#
#     Registration number / CIN & registration date  \
# 0                            S/41220 - 14-01-2002
# 1                       1755 of 1989 - 11-08-1989
# 2                MYN-4-00326-2010-11 - 08-11-2010
# 3                       397/ IV / 06 - 08-05-2006
# 4                 S/674950/ 1991- 92 - 04-04-1991
# ..                                            ...
# 546                  F/294/PORBANBAR - 10-10-2007
# 547                          Mah-963 - 05-03-2012
# 548                            12237 - 10-04-2001
# 549                       U72900DL20 - 20-01-2012
# 550                           No.290 - 28-03-2012
#
#     12A registration number & registration date  \
# 0                             1242 - 14-03-2003
# 1              H.Qrs11/12A&80G/32/ - 19-10-1990
# 2             D-54/12AA/MYS2011-12 - 27-06-2011
# 3             CIT-TCR/Tech/12A/18/ - 06-02-2012
# 4                                           NaN
# ..                                          ...
# 546                                         NaN
# 547                                         NaN
# 548                                         NaN
# 549                                         NaN
# 550                                         NaN
#
#     80G registration number & registration date  \
# 0                          8263043 - 11-10-2011
# 1             HYD/80G/155(3)/08-09 - 10-09-2008
# 2             D-54/12AA/MYS2011-12 - 08-11-2010
# 3             AADTA 2673 C/09/15-1 - 28-05-2015
# 4                                           NaN
# ..                                          ...
# 546                                         NaN
# 547                                         NaN
# 548                                         NaN
# 549                                         NaN
# 550                                         NaN
#
#     FCRA registration number & registration date  \
# 0                         231660609 - 12-12-2005
# 1                         010260111 - 05-08-2016
# 2                         094590221 - 22-12-2016
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 546                                          NaN
# 547                                          NaN
# 548                                          NaN
# 549                                          NaN
# 550                                          NaN
#
#     35AC registration number & registration date  ...  \
# 0                                            NaN  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3                                            NaN  ...
# 4                                            NaN  ...
# ..                                           ...  ...
# 546                                          NaN  ...
# 547                                          NaN  ...
# 548                                          NaN  ...
# 549                                          NaN  ...
# 550                                          NaN  ...
#
#                                    Project description  \
# 0    Project description Drug De-addiction & Rehabi...
# 1    Project description BREAD Society seeks out sc...
# 2    Project description “Divya Jyothi Charitable T...
# 3    Project description The ATMA Harmony Centre cu...
# 4    Project description Calcutta Rescue recognizes...
# ..                                                 ...
# 546                                                NaN
# 547                                                NaN
# 548                            Project description N/A
# 549                            Project description N/A
# 550                            Project description N/A
#
#                                                   Logo  \
# 0    http://www.ngoimpact.com/ngoadmin/public/ngo_p...
# 1    http://www.ngoimpact.com/ngoadmin/public/ngo_p...
# 2    http://www.ngoimpact.com/ngoadmin/public/ngo_p...
# 3    http://www.ngoimpact.com/ngoadmin/public/ngo_p...
# 4    http://www.ngoimpact.com/ngoadmin/public/ngo_p...
# ..                                                 ...
# 546  http://www.ngoimpact.com/resources/assets/imag...
# 547  http://www.ngoimpact.com/resources/assets/imag...
# 548  http://www.ngoimpact.com/resources/assets/imag...
# 549  http://www.ngoimpact.com/resources/assets/imag...
# 550  http://www.ngoimpact.com/resources/assets/imag...
#
#                                                   Name  \
# 0    Turning Point Foundation Best Non-Government O...
# 1    Basic Research Education And Development Socie...
# 2    Divya Jyothi Charitable Trust Best Non-Governm...
# 3    ATMA Foundation Best Non-Government Organizati...
# 4    Calcutta Rescue Best Non-Government Organizati...
# ..                                                 ...
# 546  YOUTH UNION FOR VARIOUS ACTION Best Non-Govern...
# 547  YUGANT FOUNDATION Best Non-Government Organiza...
# 548  Zakat Foundation Of India Best Non-Government ...
# 549  ZMQ Development Best Non-Government Organizati...
# 550  Youth For Seva Best Non-Government Organizatio...
#
#                                          About Founder  \
# 0    perm_identity Founded by Mr. Jojo Thomas ( 25 ...
# 1    perm_identity Founded by Mr. Ramamohan Rao Kak...
# 2    perm_identity Founded by Shiv Prakash ( 07 yea...
# 3    perm_identity Founded by C.k Suresh ( 30 years...
# 4    perm_identity Founded by Jack Preger ( 35 year...
# ..                                                 ...
# 546  perm_identity Founded by Hasmukh ( 15 years of...
# 547  perm_identity Founded by Prajakta Deshmukh ( 1...
# 548  perm_identity Founded by Jermy ( 15 years of e...
# 549  perm_identity Founded by Arvind ( 15 years of ...
# 550  perm_identity Founded by Kamal ( 15 years of e...
#
#                                                Address  \
# 0    room A-528, Near Dayal Market, Narela Road, Al...
# 1    room Plot # 1300 A, Jubilee Hills,, Road # 66,...
# 2    room No.151/f, Premises of Bapuji Children's H...
# 3    room ATMA Foundation, Surya Gardens,, Paliyam ...
# 4    room Calcutta Rescue 4th Floor, 85 Collin Stre...
# ..                                                 ...
# 546  room 1, nishant Bunglows, Near Bariz Avenew So...
# 547  room 7, DAULAT, OPP. GAJAPANTH NAGAR, NEAR AAD...
# 548      room aaaaaa, acastr, New Delhi, Delhi- 110007
# 549       room cacac, sadeft, New Delhi, Delhi- 110007
# 550     room asde, cacac, Bengaluru, Karnataka- 543123
#
#                                           URL  \
# 0                     http://www.tpfindia.org
# 1    http://http://www.breadsocietyindia.org/
# 2             http://www.divyajyothitrust.org
# 3               http://www.atmafoundation.org
# 4               http://www.calcuttarescue.org
# ..                                        ...
# 546                                       NaN
# 547                                       NaN
# 548                                       NaN
# 549                     http://www.zmqdev.org
# 550        http://http://www.youthforseva.org
#
#                                 Area of focus Geographical Activity  \
# 0                     Healthcare / Prevention                 Delhi
# 1                                   Education        Andhra Pradesh
# 2                                  Disability             Karnataka
# 3    Promotion And Protection Of Child Rights                Kerala
# 4                                   Education           West Bengal
# ..                                        ...                   ...
# 546         Livelihoods / Poverty Alleviation               Gujarat
# 547         Livelihoods / Poverty Alleviation           Maharashtra
# 548                       Disaster Management                 Delhi
# 549         Livelihoods / Poverty Alleviation                 Delhi
# 550            Vocational And Skills Training             Karnataka
#
#     Project Completed  Funding requirement
# 0                 5.0            1500000.0
# 1                18.0            3500000.0
# 2                18.0            1500000.0
# 3                 0.0                  0.0
# 4                12.0            1500000.0
# ..                ...                  ...
# 546               0.0                  0.0
# 547               0.0                  0.0
# 548               0.0                  0.0
# 549               0.0                  0.0
# 550               0.0                  0.0
#
# [551 rows x 50 columns]

# %% [markdown]
# # 2. Dataset Characteristics

# %%
print("Shape:",ngoimpact.shape)
print("Rows:",ngoimpact.shape[0])
print("Columns:",ngoimpact.shape[1])
print("Each row represents a NGO in India. Gives some information about each organization's vision, what they're registered as, project descriptions, etc.")
# Out:
# Shape: (551, 50)
# Rows: 551
# Columns: 50
# Each row represents a NGO in India. Gives some information about each organization's vision, what they're registered as, project descriptions, etc.

# %%
len(ngoimpact)
# Out:
# 551

# %%
# list of all the columns in the dataset
p = pd.DataFrame(ngoimpact.columns)
p
# Out:
#                                                     0
# 0                                                Link
# 1                                               About
# 2                                              VISION
# 3                  Your organisation is registered as
# 4                      Permanent account number (PAN)
# 5       Registration number / CIN & registration date
# 6         12A registration number & registration date
# 7         80G registration number & registration date
# 8        FCRA registration number & registration date
# 9        35AC registration number & registration date
# 10                                      Annual budget
# 11                                       Total income
# 12                                  Total expenditure
# 13                        Average monthly expenditure
# 14                                 Total fixed assets
# 15                                     Long term loan
# 16                                  Total funding gap
# 17                      Number of full time employees
# 18                      Number of part time employees
# 19                              Number of consultants
# 20                     Number of volunteers / interns
# 21  Which operational area do you require addition...
# 22                            Number of board members
# 23                            Number of meetings done
# 24                                  Governance photos
# 25                               Governance documents
# 26                        Who are your major funders?
# 27                                  Name your funders
# 28                                 Project start date
# 29                    Project end/expected close date
# 30                                     Project Sector
# 31                                           Location
# 32                                          City(ies)
# 33                                     Area/Town name
# 34                                             Budget
# 35                          External funding received
# 36                            Number of beneficiaries
# 37                                       Project type
# 38                                     Project photos
# 39                                  Project documents
# 40                                Project description
# 41                                               Logo
# 42                                               Name
# 43                                      About Founder
# 44                                            Address
# 45                                                URL
# 46                                      Area of focus
# 47                              Geographical Activity
# 48                                  Project Completed
# 49                                Funding requirement

# %% [markdown]
# # 3. EDA

# %%
ngoimpact = ngoimpact.rename(columns = {"Your organisation is registered as": "Registered as"})

# %%
counts_impact = ngoimpact["Registered as"].value_counts(ascending = False)
counts_impact
# Out:
# Public Charitable Trust    356
# Charitable Society         149
# Section 8 Company            7
# Name: Registered as, dtype: int64

# %%
geog = ngoimpact["Geographical Activity"].value_counts(ascending = False)
geog
# Out:
# Delhi                182
# Maharashtra           79
# West Bengal           42
# Tamil Nadu            39
# Odisha                32
# Karnataka             24
# Gujarat               21
# Uttar Pradesh         17
# Bihar                 16
# Andhra Pradesh        11
# Haryana                9
# Madhya Pradesh         9
# Himachal Pradesh       9
# Rajasthan              9
# Jharkhand              8
# Telangana              8
# Assam                  6
# Kerala                 4
# Uttarakhand            3
# Arunachal Pradesh      2
# Goa                    2
# Manipur                1
# Tripura                1
# Chandigarh             1
# Chhattisgarh           1
# Pondicherry            1
# Name: Geographical Activity, dtype: int64

# %%
area_funding = pd.DataFrame(ngoimpact.groupby("Area of focus").mean()["Funding requirement"])
area_funding
# Out:
#                                                     Funding requirement
# Area of focus
# Advocacy                                                   2.833333e+05
# Community Development                                      7.359375e+05
# Disability                                                 1.333333e+06
# Disaster Management                                        4.000000e+05
# Education                                                  1.662545e+06
# Elderly Care                                               0.000000e+00
# Environment                                                2.409375e+06
# Gender Mainstreaming                                       5.000000e+04
# Healthcare / Prevention                                    1.321429e+06
# Livelihoods / Poverty Alleviation                          5.332707e+05
# Maternal And Child Health                                  3.750000e+05
# Promotion And Protection Of Child Rights                   1.805214e+06
# Promotion And Protection Of National Heritage, ...         1.500000e+06
# Rural Development                                          1.467857e+06
# Vocational And Skills Training                             1.250000e+06
# Women Empowerment                                          7.407461e+10
# Youth Empowerment                                          9.000000e+05

# %%
sns.barplot(data = area_funding, x = "Funding requirement", y = area_funding.index)
# Out:
# <AxesSubplot:xlabel='Funding requirement', ylabel='Area of focus'>

# %% [markdown]
# #### We see here that Women Empowerment is the area with the most amount of funding, on average, by far. To better visualize the funding distribution, we will drop Women Empowerment and create another bar chart.

# %%
area_funding.drop("Women Empowerment", axis = 0, inplace = True)
sns.barplot(data = area_funding, x = "Funding requirement", y = area_funding.index)
# Out:
# <AxesSubplot:xlabel='Funding requirement', ylabel='Area of focus'>

# %% [markdown]
# ### This could be the start of further analysis. We could investigate why Women Empowerment has higher funding requirements relative to other areas, and why an area such as elderly care or poverty alleviation takes so little.

# %% [markdown]
# ### Another aspect to investigate is the relationship between geographical location and the average funding requirements, which we will do now.

# %%
geog_funding = pd.DataFrame(ngoimpact.groupby("Geographical Activity").mean()["Funding requirement"])
geog_funding.sort_values("Funding requirement", ascending = False)
# Out:
#                        Funding requirement
# Geographical Activity
# Assam                         3.703704e+11
# Maharashtra                   2.972831e+06
# Gujarat                       2.965476e+06
# Madhya Pradesh                2.896111e+06
# Tripura                       2.500000e+06
# Pondicherry                   1.200000e+06
# Manipur                       1.200000e+06
# Uttar Pradesh                 1.000000e+06
# Bihar                         9.437500e+05
# Odisha                        8.265625e+05
# Delhi                         5.898902e+05
# Andhra Pradesh                5.636364e+05
# Uttarakhand                   5.333333e+05
# Karnataka                     5.166667e+05
# Tamil Nadu                    3.846154e+05
# Himachal Pradesh              3.333333e+05
# Haryana                       3.277778e+05
# Telangana                     3.062500e+05
# Rajasthan                     2.888889e+05
# Jharkhand                     2.625000e+05
# West Bengal                   1.535714e+05
# Arunachal Pradesh             0.000000e+00
# Goa                           0.000000e+00
# Chhattisgarh                  0.000000e+00
# Chandigarh                    0.000000e+00
# Kerala                        0.000000e+00

# %% [markdown]
# ### We can again clearly see one state, Assam, has the highest average funding requirement by far. Keeping that in mind, we will drop the row and plot the rest to get an understanding of the other datapoints.

# %%
geog_funding.drop("Assam", axis = 0, inplace = True)
geog_funding
# Out:
#                        Funding requirement
# Geographical Activity
# Andhra Pradesh                5.636364e+05
# Arunachal Pradesh             0.000000e+00
# Bihar                         9.437500e+05
# Chandigarh                    0.000000e+00
# Chhattisgarh                  0.000000e+00
# Delhi                         5.898902e+05
# Goa                           0.000000e+00
# Gujarat                       2.965476e+06
# Haryana                       3.277778e+05
# Himachal Pradesh              3.333333e+05
# Jharkhand                     2.625000e+05
# Karnataka                     5.166667e+05
# Kerala                        0.000000e+00
# Madhya Pradesh                2.896111e+06
# Maharashtra                   2.972831e+06
# Manipur                       1.200000e+06
# Odisha                        8.265625e+05
# Pondicherry                   1.200000e+06
# Rajasthan                     2.888889e+05
# Tamil Nadu                    3.846154e+05
# Telangana                     3.062500e+05
# Tripura                       2.500000e+06
# Uttar Pradesh                 1.000000e+06
# Uttarakhand                   5.333333e+05
# West Bengal                   1.535714e+05

# %%
sns.barplot(data = geog_funding, x = "Funding requirement", y = geog_funding.index)
# Out:
# <AxesSubplot:xlabel='Funding requirement', ylabel='Geographical Activity'>
